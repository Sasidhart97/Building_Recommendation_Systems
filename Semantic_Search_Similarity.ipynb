# %%
import logging
from pprint import pprint
from gensim import corpora
from gensim import models
from gensim import similarities
from gensim.test.utils import get_tmpfile
from nltk.corpus import stopwords
import warnings
warnings.filterwarnings("ignore")

# %%
def generateSimilarityIndex(corpus, num_topics=100):
    ##############################################################
    # Create TFIDF and LSI Models on the corpus
    ##############################################################
    tfidfModel = models.TfidfModel(corpus)
    corpus_tfidf = tfidfModel[corpus]

    # Reduce to 100 dimensions
    lsiModel = models.LsiModel(corpus_tfidf, id2word=dictionary,
                               num_topics=num_topics)  # initialize an LSI transformation
    # lsi_model = models.LdaModel(corpus_tfidf, id2word=dictionary, num_topics=10)  # initialize an LSI transformation
    # lsi_model = models.HdpModel(corpus_tfidf, id2word=dictionary)  # initialize an LSI transformation
    corpus_lsi = lsiModel[corpus_tfidf]  # create a double wrapper over the original corpus: bow->tfidf->fold-in-lsi

    # Print the topics generated by the lsi model
    lsiModel.print_topics()

    # Create an index on which if we hit we will get the
    # similarity of the hitting object with all these documents
    # in LSI space

    # In memory computation - better for small datasets that fit in memory
    # index = similarities.MatrixSimilarity(corpus_lsi)  # transform corpus to LSI space and index it

    # Non In memory computation - better for big datasets that dont fit in memory
    index_temp = get_tmpfile("lsimodel")  # create a temporary file named lsimodel to save things
    # Note that you need to give num_topics again here as num_features
    index = similarities.Similarity(index_temp, corpus_lsi,
                                    num_features=num_topics)  # transform corpus to LSI space and index it

    return [index, tfidfModel, lsiModel]

# %%
# Import the logging module for gensim
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# Load the dataset
f = open('./rawData.csv', 'rb')
data = f.readlines()

documents = []
for document in data:
    documents.append(document)

# %%
# Remove common words and tokenize
stoplist = set('for a of the and to in'.split())

texts = []
i = 0
idToDocumentDict = {}  # id-> document
for document in documents:
    s = [word for word in document.lower().split() if word not in stoplist]
    s = [x for x in s if x not in set(stopwords.words('english'))]
    texts.append(s)
    idToDocumentDict[i] = document
    i += 1

# %%
# Create a dictionary
dictionary = corpora.Dictionary(texts)
# pprint(dictionary)

# Create a corpus
corpus = [dictionary.doc2bow(text) for text in texts]
# pprint(corpus)

# Create the TFIDF and LSI Models
[index, tfidfModel, lsiModel] = generateSimilarityIndex(corpus, num_topics=100)

# Transform the search keyword to lsi space
search_text = 'kidnap'.lower().split()
# Out:
# 2019-11-16 16:54:00,545 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2019-11-16 16:54:00,600 : INFO : built Dictionary(10190 unique tokens: ['"in', '"the', '100', '4:00pm', '500']...) from 300 documents (total 59881 corpus positions)
# 2019-11-16 16:54:00,652 : INFO : collecting document frequencies
# 2019-11-16 16:54:00,653 : INFO : PROGRESS: processing document #0
# 2019-11-16 16:54:00,659 : INFO : calculating IDF weights for 300 documents and 10189 features (38568 matrix non-zeros)
# 2019-11-16 16:54:00,681 : INFO : using serial LSI version on this node
# 2019-11-16 16:54:00,682 : INFO : updating model with new documents
# 2019-11-16 16:54:00,814 : INFO : preparing a new chunk of documents
# 2019-11-16 16:54:00,822 : INFO : using 100 extra samples and 2 power iterations
# 2019-11-16 16:54:00,822 : INFO : 1st phase: constructing (10190, 200) action matrix
# 2019-11-16 16:54:00,833 : INFO : orthonormalizing (10190, 200) action matrix
# 2019-11-16 16:54:01,426 : INFO : topic #17(1.298): -0.235*"friedli" + -0.145*"replied:" + -0.120*"afghan" + -0.119*"company" + -0.109*"21" + -0.108*"interim" + -0.103*"director" + 0.099*"training" + 0.095*"they" + 0.087*"guides"
# 2019-11-16 16:54:01,427 : INFO : topic #18(1.272): 0.122*"indian" + 0.088*"side" + -0.087*"man" + 0.085*"tailenders" + 0.084*"waugh" + -0.080*"lockett" + 0.076*"report" + 0.075*"deaths." + 0.071*"rates" + -0.071*"training"
# 2019-11-16 16:54:01,428 : INFO : topic #19(1.265): -0.195*"asylum" + -0.145*"pacific" + 0.139*"space" + -0.118*"nauru" + -0.105*"holiday" + -0.104*"seekers" + -0.103*"recorded" + 0.101*"centre" + -0.099*"boat" + -0.097*"ruddock"
# 2019-11-16 16:54:01,428 : INFO : starting similarity index under C:\Users\sasid\AppData\Local\Temp\lsimodel

# %%
# Get its bag of words
corpus_search_keyword = dictionary.doc2bow(search_text)
# print 'corpus_search_keyword:', corpus_search_keyword

tfidf_search_keyword = tfidfModel[corpus_search_keyword]
# print 'tfidf_search_keyword:', tfidf_search_keyword

lsi_search_keyword = lsiModel[tfidf_search_keyword]
# print 'lsi_search_keyword:',lsi_search_keyword

#################################################################
# find the similarity of search keyword to the documents in lsi space

sims = index[lsi_search_keyword]  # perform a similarity query against the corpus
# print(list(enumerate(sims)))  # print (document_number, document_similarity) 2-tuples

sims = sorted(enumerate(sims), key=lambda item: -item[1])

# sims = sorted(enumerate(sims), key=lambda item: -item[-1][1])

count = 0
articles2bsent = []
maxArticlesTobSent = 10
for internal_id, (document_id, lsicosine) in enumerate(sims):
    article = idToDocumentDict[document_id]
    # print(internal_id, (document_id, lsicosine), article)

    articles2bsent.append(article)
    if count >= maxArticlesTobSent:
        break

    count += 1

pprint(articles2bsent)
# Out:
# 2019-11-16 16:54:01,618 : INFO : creating matrix with 300 documents and 100 features
# 2019-11-16 16:54:01,619 : INFO : creating dense shard #0
# 2019-11-16 16:54:01,620 : INFO : saving index shard to C:\Users\sasid\AppData\Local\Temp\lsimodel.0
# 2019-11-16 16:54:01,620 : INFO : saving MatrixSimilarity object under C:\Users\sasid\AppData\Local\Temp\lsimodel.0, separately None
# 2019-11-16 16:54:01,622 : INFO : saved C:\Users\sasid\AppData\Local\Temp\lsimodel.0
# 2019-11-16 16:54:01,623 : INFO : loading MatrixSimilarity object from C:\Users\sasid\AppData\Local\Temp\lsimodel.0
# 2019-11-16 16:54:01,631 : INFO : loaded C:\Users\sasid\AppData\Local\Temp\lsimodel.0
# [b'A British man has been found guilty by a unanimous verdict of the kidnap and'
#  b' murder of an eight-year-old schoolgirl whose death in July 2000 shocked Bri'
#  b'tain and set off a rampage of anti-paedophile vigilantes. Roy Whiting was se'
#  b'ntenced to life imprisonment for the abduction and murder of eight-year-old '
#  b'Sarah Payne with a recommendation by trial judge Justice Richard Curtis that'
#  b' he never be released. "You are indeed an evil man. You are in no way mental'
#  b'ly unwell. I have seen you for a month and in my view you are a glib and cun'
#  b'ning liar," Justice Curtis said. There were cheers of delight as the verdict'
#  b's were read out by the foreman at Lewes Crown Court. The jury of nine men an'
#  b'd three women had been deliberating for nine hours. As soon as the verdicts '
#  b"were declared, the court heard details of Whiting's previous conviction for "
#  b'the kidnap and indecent assault of a nine-year-old girl in 1995. Prosecutor '
#  b'Timothy Langdale told the jury how the defendant threw the child into the ba'
#  b'ck of his dirty red Ford Sierra and locked the doors. "He had driven her som'
#  b"ewhere. She didn't know where. When she asked where they were going he said,"
#  b' \'shut up\', because he had a knife," Mr Langdale said. "The defendant to'
#  b'ld the girl to take off her clothes. When she refused, he produced a rope fr'
#  b'om his pocket and threatened to tie her up. "What he actually threatened was'
#  b' that he would \'tie her mouth up\'. "She took her clothes off as he had o'
#  b'rdered her to do." Mr Langdale then gave graphic details of the abuse to whi'
#  b'ch Whiting subjected the terrified child. Whiting was given a four-year jail'
#  b' sentence in June 1995 after admitting carrying out the attack in March that'
#  b' year. But he was released in November 1997 despite warnings from probation '
#  b'officers, who were convinced there was a danger he would attack another chil'
#  b'd. They set out their warnings in a pre-sentence report, prepared after the '
#  b'first assault, and in the parole report before he was released from prison. '
#  b'He was kept under supervision for four months after his release, but was not'
#  b' being monitored by July last year, when eight-year-old Sarah was abducted a'
#  b'nd killed. Whiting has been arrested three times in connection with the case'
#  b', but the first and second times was released without being charged. Sarah d'
#  b'isappeared on July 1 last year, prompting a massive police search. Her parti'
#  b'ally-buried naked body was found 16 days later in a field and police believe'
#  b' she was strangled or suffocated.\n',
#  b'The United States team of Monica Seles and Jan-Michael Gambill scored a deci'
#  b'sive victory over unseeded France in their first Hopman Cup match at Burswoo'
#  b'd Dome in Perth. The pair, runners-up in the $1 million dollar mixed teams e'
#  b'vent last year, both won their singles encounters to give the US an unbeatab'
#  b'le 2-0 lead. The 28-year-old Seles, currently ranked eighth, recovered from '
#  b'a shaky start to overpower Virginie Razzano, 18, who is ranked 72nd. Seles h'
#  b'ad to fight hard to get home in straight sets, winning 6-3, 6-4 in 62 minute'
#  b's. Then the 24-year-old Gambill (ranked 21st) wore down a determined Arnaud '
#  b'Clement, 24, (18th) to win 6-4, 6-4 in 91 minutes. The Americans are aiming '
#  b'to go one better than last year when they were beaten by Swiss pair Martina '
#  b'Hingis and Roger Federer in the final of the eight-nation contest. Gambill s'
#  b'aid the win was a great way to start the tennis year. "I got a little tentat'
#  b'ive at the end, but it was a great start to my year," he said. "Arnaud is a '
#  b'great scrapper and I am delighted to beat him, even though I am frankly a bi'
#  b't out of shape. "That is one of the reasons I am here. I will be in shape by'
#  b' the end of the tournament. "I just aim to keep improving in the new year, a'
#  b'nd if I do, I think I have a chance to beat anyone when I am playing well." '
#  b'Gambill was pressed hard by Clement before taking the first set in 47 minute'
#  b's. But the American gained the ascendancy in the second set, breaking in the'
#  b' third and fifth games. Seles said she had expected her clash with Razzano t'
#  b'o be tough. "She was a top junior player in the world, so it was no surprise'
#  b' that she fought so well," she said. Seles said she still had the hunger to '
#  b'strive to regain her position at the top of her sport. "This is why you play'
#  b'," she said. "But I want to try not to peak too early this season. "Seles, s'
#  b'low into her stride, slipped to 2-3 in her opening set against Razzano but r'
#  b'ecovered quickly, claiming the set after snatching four games in a row. In t'
#  b'he second set, Seles broke her opponent in the opening game and completed vi'
#  b"ctory with relative ease despite Razzano's tenacious efforts.\n",
#  b"New Zealand's ambassador to Brazil, Denise Almao, said she had identified th"
#  b'e body of murdered sea hero Sir Peter Blake, but she would not say how he di'
#  b'ed. According to initial police reports, Mr Blake was shot dead by pirates w'
#  b'ho bordered his yacht, Seamaster, off the town of Macapa, in the mouth of th'
#  b'e Amazon River. He was said to have been shot twice in the back, although hi'
#  b's mother said she had been told that he was shot in the head. Joyce Blake al'
#  b'so told Radio New Zealand that unidentified people had held a grudge against'
#  b' her son. Ms Almao told the radio station she had gone to Macapa to identify'
#  b' the body. "He was shot twice," she said. She would not say if he was shot i'
#  b'n the back. Two other crew members who were injured in the attack had been t'
#  b'reated in hospital and had returned to the Seamaster, Ms Almao said. "They s'
#  b'eem okay. The injuries they suffered were not serious." New Zealand Prime Mi'
#  b'nister Helen Clark says she feels devastated by Mr Blake\'s death. "I thi'
#  b'nk he is to the waters what Sir Edmund Hillary has been to the mountains. Yo'
#  b'u couldn\'t find a more public-spirited man than this," she said. Ms Alma'
#  b'o said Brazilians were also in shock and were providing every sort of assist'
#  b'ance. "My impression is that there is a very active investigation proceeding'
#  b', that everyone from the governor on down is offering every assistance and I'
#  b' think they are doing their utmost to bring the perpetrators to justice," sh'
#  b'e said.\n',
#  b'The members of the newly-elected Solomon Islands Parliament meet today to ch'
#  b'oose a prime minister. The much-criticised finance minister in the last gove'
#  b'rnment, Snyder Rini, could have the numbers to win. The prime minister who w'
#  b"as forced to resign after last year's coup, Batholomew Ulufa'alu, has told n"
#  b'ational radio he has heard rumours that if he is elected there could be anot'
#  b'her coup. That is one of the reasons the group he hoped to lead dumped him l'
#  b'ast week in favour of his former foreign minister, Patterson Oti. The person'
#  b' with the longest list of supporters is Mr Rini, who has given massive impor'
#  b't duty remissions on beer and cigarettes to favoured importers despite the p'
#  b"arlous state of the Government's finances. The editor of a British tabloid h"
#  b'as defended the resumption of its name and shame campaign against paedophile'
#  b's saying parents have the right to know of potential dangers in the communit'
#  b'y. The paper published the names of convicted paedophiles who had failed to '
#  b'submit their names to the sex offenders register. The News of the World crea'
#  b'ted uproar last year when it published the names and addresses of child sex '
#  b'offenders with vigilante groups formed and in some cases attacking the wrong'
#  b' men. The latest campaign, which is limited to naming those who have abscond'
#  b'ed without registering, comes in the wake of the conviction of known paedoph'
#  b'ile Roy Whiting for the murder of eight-year-old Sarah Payne. News of the Wo'
#  b'rl editor Rebekah Wade says it is the public\'s right to know. "If you ha'
#  b"ve paedophiles in society that aren't monitored, they will strike again,"
#  b'" she said. "If the police cannot monitor them, then it is only right and fa'
#  b'ir if you have a family with three young children then you have a general ri'
#  b'ght to know that to protect your children." British Home Secretary David Blu'
#  b'nkett has promised more community involvement in the supervision of known of'
#  b'fenders.\n',
#  b'The Greens have officially won their second Senate spot in Federal Parliamen'
#  b't. The Senate count for New South Wales has been finalised with Kerry Nettle'
#  b' from the Greens taking the final position from long time Democrats Senator '
#  b'Vicki Bourne. Senator Bourne says she is very lucky to have served in the Pa'
#  b'rliament for 12 years and has nominated serving as an observer at the East T'
#  b'imor independence ballot as the high point of her career. She has wished Ker'
#  b'ry Nettle well, saying it is a great honour and a great responsibility to be'
#  b' elected to the Senate.\n',
#  b'Australian families of the victims from the Interlaken tragedy have welcomed'
#  b" today's guilty verdicts against six employees from the Adventure World cany"
#  b'oning tour company. A Swiss court has found the six of the eight employees g'
#  b'uilty of culpable manslaughter after the tragedy which killed 21 people, 14 '
#  b'of them Australians. They have been given suspended jail sentences of up to '
#  b'five-months and fined between $5,000 and $7,000. Two guides who survived wer'
#  b'e acquitted. Gary Redmond, who lost his 26-year-old son Scott and 24-year-ol'
#  b'd daughter-in-law Alissa, says he is satisfied and relieved with the outcome'
#  b'. "All along we hoped that justice would prevail and that whatever the penal'
#  b'ties that apply in Switzerland that are appropriate should apply," Mr Redmon'
#  b'd said. Some of the families are threatening civil action, but Mr Redmond sa'
#  b'ys the verdict means closure for his family "I\'m not of the view that an'
#  b'ything that now comes out of this whether there be any further benefit to ac'
#  b'crue to us or the survivors, that it will in any way compensate for the loss'
#  b' of our loved ones," Mr Redmond said. The families say that they are still t'
#  b'o receive an apology from Adventure World, but Bill Peel, whose son Billy di'
#  b'ed in the 1999 canyoning accident and is in Switzerland for the court hearin'
#  b'g, has welcomed today\'s verdicts "I always felt that they were guilty be'
#  b'cause the duty of care was never used...and now the judge has confirmed ever'
#  b'ything we believed," Mr Peel said. The family of a Bendigo woman killed in t'
#  b"he canyon disaster has also welcomed the verdict. Kylie Morrow's mother Eliz"
#  b'abeth, says the verdict has made the tour guides accountable for their negli'
#  b'gence, and proves the young people who lost their lives did not act reckless'
#  b'ly. "I\'m not sure where we go from here but you know we\'ve got other chi'
#  b"ldren and we've got each other and family and life goes on even when you don"
#  b'\'t want it to sometimes. "Our lives have been changed forever and nothin'
#  b"g that happens from now on can be any worse than what we've been through"
#  b'," Ms Morrow said.\n',
#  b'A project working on ways to reduce the debt of prisoners in Australian jail'
#  b"s has run out of money. The Criminal Justice Coalition's Prison and Debt Pro"
#  b'ject has been developing tools to educate prisoners and their families about'
#  b' their financial rights. Spokeswoman Anne Stringer says funding from a non-p'
#  b'rofit organisation has run out and she is now looking for government support'
#  b' to trial the education programs. Ms Stringer says if  successful, the progr'
#  b'ams may stop prisoners from reoffending to repay accumulated debt. "As soon '
#  b'as you get out of prison, Centrelink starts deducting the money you owe them'
#  b' from your benefit payment so your income is vastly reduced," she said. "You'
#  b" may not have a place to live and your car's probably been repossessed. "
#  b'"Your chances of getting employment and starting to pay back the debt is ver'
#  b'y very slim."\n',
#  b"The Northern Territory's coroner has found that an Aboriginal boy who died i"
#  b'n custody nearly two years ago should not have to be in detention. In Februa'
#  b'ry last year, the teenager died in hospital from compression of the neck aft'
#  b'er hanging himself in the Don Dale Juvenile Detention Centre. In his report,'
#  b' the coroner, Dick Wallace, said the 15-year-old was a lonely and negelected'
#  b' orphan who had been offending since he was 13. In January last year, the te'
#  b'enager was given a mandatory 28-day sentence for stealing stationery. Howeve'
#  b'r, the coroner said the boy had been eligible to undertake a diversionary pr'
#  b'ogram of victim-offender conferencing instead of being sent to detention. Th'
#  b'e court had not considered that option and neither the prosecutor nor the bo'
#  b"y's lawyer had told the magistrate there was an alternative to a custodial s"
#  b'entence.\n',
#  b'The Queensland Premier says he accepts full responsibility for a mentally il'
#  b'l killer being able to flee overseas. Claude John Gabriel stabbed to death a'
#  b' Gold Coast teenager in 1998 and was receiving treatment for a mental illnes'
#  b's. However, he absconded from a Queensland mental health facility earlier th'
#  b'is year and went to live in Melbourne. He is now thought to be in Rome. Prem'
#  b'ier Peter Beattie says the Queensland Government is seeking legal advice abo'
#  b'ut whether it can force Gabriel to return. "Why he had a passport is beyond '
#  b"me I have to tell you and I'm pretty cranky about that, that he had a passpo"
#  b'rt and left the country," he said. "I\'m very unhappy about how this whol'
#  b'e matter has been handled and I\'ve made that very clear."\n',
#  b'Australia will be aiming to take early wickets on day two of the second cric'
#  b'ket Test against South Africa at the MCG. The Proteas will resume at three f'
#  b'or 89 after day one was badly affected by rain with only 40 overs possible. '
#  b'Australian paceman Glenn McGrath, who has two wickets, says the catch taken '
#  b"by Matthew Hayden yesterday is typical of Australia's outstanding slips fiel"
#  b'ding this summer. "In the series so far there\'s been some great catches '
#  b'- Ricky Ponting in the last Test, occasionally I get one myself," he said. "'
#  b'It gives you so much more confidence when you know 99 per cent of the catche'
#  b's that go flying to the slips or through the slips are going to be taken'
#  b'."\n',
#  b'Six Swiss tour company staff have been found guilty of manslaughter over the'
#  b' deaths of 14 Australians and seven others in a canyoning disaster. Two guid'
#  b'es who survived the accident on July 27, 1999, were acquitted. Adventure Wor'
#  b'ld president Stephan Friedli, vice-president Peter Balmer and director Georg'
#  b' Hoedle were each given a five-month suspended sentence and a fine of 7,500 '
#  b'Swiss francs (about $A8,800). General manager Felix Oehler received five mon'
#  b'ths and a fine of 5,000 francs, base manager Bernhard Gafner four months and'
#  b' 4,000 francs, and lead guide Bernhard Steuri three months and 4,000 francs.'
#  b' All six will pay one-eighth of the court costs and one-eighth of the plaint'
#  b"iffs' costs, about 27,000 francs each. Guides Simon Wiget and Stefan Abeggle"
#  b'n were acquitted. Peter Dewar, whose son Bradley died in the 1999 disaster, '
#  b'says more legal action is planned. "I guess if anything the main thing we we'
#  b're waiting for was a verdict of guilty or not guilty," Mr Dewar said. "The g'
#  b'uilty verdict at least leaves something open for civil action, we already ha'
#  b've legal representation in place." Mr Dewar said he hopes civil action would'
#  b' be a further "form of punishment for the guilty". Bill Peel of Mackay in no'
#  b'rth Queensland, whose son Billy died in the canyoning accident, is disappoin'
#  b'ted with the verdict. "It\'s Swiss law and we have to abide by it, I was '
#  b'very angry, very angry I couldn\'t believe it. "We were told this when th'
#  b'e lawyer came to Australia 18 months ago but it was still hard to believe it'
#  b' was true...oh well at least they are guilty and they have to live that the '
#  b'rest of their lives and that\'s some punishment anyway," Mr Peel said.\n']
